# %%
# импорты
import pandas as pd
import xlrd

# %%
# чтение данных в список датафреймов
dfs = []
rb = xlrd.open_workbook('data.xlsx')
for item in rb.sheets():
    if item.name[:2].lower() == 'uz':
        df = pd.read_excel('data.xlsx', item.name)
        df['id'] = item.name
        print(df)
# Out:
#          TVD      GR    NGK   NKTD      DTP     id
# 0    842.031  10.257  0.899  1.914  343.124  UZ-12
# 1    842.130   9.947  0.945  1.860  339.601  UZ-12
# 2    842.228   9.366  0.949  1.923  340.717  UZ-12
# 3    842.327   8.050  0.944  2.017  331.685  UZ-12
# 4    842.426   6.654  0.933  2.291  308.736  UZ-12
# ..       ...     ...    ...    ...      ...    ...
# 167  858.521   9.863  0.941  2.386  310.172  UZ-12
# 168  858.620  10.225  0.964  2.300  308.141  UZ-12
# 169  858.719  10.603  0.972  2.311  307.224  UZ-12
# 170  858.818  10.270  0.975  2.381  304.808  UZ-12
# 171  858.916  10.136  0.974  2.467  304.224  UZ-12
#
# [172 rows x 6 columns]
#          TVD      GR    NGK   NKTD      DTP     id
# 0    800.044  12.495  0.897  1.029  403.824  Uz_13
# 1    800.144  12.658  0.902  1.219  382.182  Uz_13
# 2    800.244  12.051  0.938  1.492  352.487  Uz_13
# 3    800.343  11.618  0.918  1.802  317.053  Uz_13
# 4    800.443  11.375  0.905  1.964  281.609  Uz_13
# ...

# %%
len(dfs)
# Out:
# 172
